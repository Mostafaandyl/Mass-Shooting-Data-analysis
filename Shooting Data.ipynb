# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv(r"C:\Users\qande\Downloads\archive (10)\shooting_1982-2023_cleaned.csv")
df.head(20)
# Out:
#                                     case                    location  \
# 0    Nashville religious school shooting               Nashville, TN
# 1     Michigan State University shooting      East Lansing, Michigan
# 2           Half Moon Bay spree shooting   Half Moon Bay, California
# 3          LA dance studio mass shooting   Monterey Park, California
# 4              Virginia Walmart shooting        Chesapeake, Virginia
# 5                    LGBTQ club shooting  Colorado Springs, Colorado
# 6        University of Virginia shooting   Charlottesville, Virginia
# 7                 Raleigh spree shooting   Hedingham, North Carolina
# 8           Greenwood Park Mall shooting          Greenwood, Indiana
# 9   Highland Park July 4 parade shooting     Highland Park, Illinois
# 10        Church potluck dinner shooting         Birmingham, Alabama
# 11             Concrete company shooting        Smithsburg, Maryland
# 12         Tulsa medical center shooting             Tulsa, Oklahoma
# ...

# %%
df.describe()
# Out:
#        fatalities     injured  total_victims  age_of_shooter    latitude  \
# count  141.000000  141.000000     141.000000      141.000000  141.000000
# mean     7.808511   11.248227      19.049645       33.531915   37.400822
# std      7.463162   46.571935      51.737569       13.726696    5.441899
# min      3.000000    0.000000       3.000000        0.000000   21.320063
# 25%      4.000000    1.000000       6.000000       22.000000   33.850116
# 50%      6.000000    3.000000      10.000000       32.000000   38.135992
# 75%      8.000000   10.000000      17.000000       43.000000   41.412323
# max     58.000000  546.000000     604.000000       72.000000   48.461367
#
#         longitude         year     quarter        half
# count  141.000000   141.000000  141.000000  141.000000
# mean   -96.205593  2010.382979    2.404255    1.460993
# std     17.642771    10.796600    1.140042    0.500253
# min   -157.876462  1982.000000    1.000000    1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141 entries, 0 to 140
# Data columns (total 30 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   case                              141 non-null    object
#  1   location                          141 non-null    object
#  2   date                              141 non-null    object
#  3   summary                           141 non-null    object
#  4   fatalities                        141 non-null    int64
#  5   injured                           141 non-null    int64
#  6   total_victims                     141 non-null    int64
#  7   location.1                        141 non-null    object
#  8   age_of_shooter                    141 non-null    int64
#  9   prior_signs_mental_health_issues  141 non-null    object
#  10  mental_health_details             141 non-null    object
# ...

# %%
df.isna().sum()
# Out:
# case                                0
# location                            0
# date                                0
# summary                             0
# fatalities                          0
# injured                             0
# total_victims                       0
# location.1                          0
# age_of_shooter                      0
# prior_signs_mental_health_issues    0
# mental_health_details               0
# weapons_obtained_legally            0
# where_obtained                      0
# weapon_type                         0
# weapon_details                      1
# race                                0
# gender                              0
# latitude                            0
# longitude                           0
# type                                0
# year                                0
# quarter                             0
# half                                0
# month_name                          0
# day_of_week                         0
# ...

# %%
df[["City", "State"]] = df["location"].str.split(",", expand = True)
df.head()
# Out:
#                                   case                   location        date  \
# 0  Nashville religious school shooting              Nashville, TN  2023-03-27
# 1   Michigan State University shooting     East Lansing, Michigan  2023-02-13
# 2         Half Moon Bay spree shooting  Half Moon Bay, California  2023-01-23
# 3        LA dance studio mass shooting  Monterey Park, California  2023-01-21
# 4            Virginia Walmart shooting       Chesapeake, Virginia  2022-11-22
#
#                                              summary  fatalities  injured  \
# 0  Audrey Hale, 28, who was a former student at t...           6        1
# 1  Anthony D. McRae, 43, opened fire at Berkey Ha...           3        5
# 2  Chunli Zhao, 67, suspected of carrying out the...           7        1
# 3  Huu Can Tran, 72, fled the scene in a white va...          11       10
# 4  Andre Bing, 31, who worked as a supervisor at ...           6        6
#
# ...

# %%
plt.figure(figsize = (16 ,8))
fdf = sns.barplot(x= "race", y = "total_victims", data = df, palette="deep")

# %%
df = df.drop(["latitude","description","longitude" ], axis = 1)

# %%
explode = [0.2, 0, 0.4,0.2, 0, 0.4, 0.3]

df.groupby("race").sum().plot(kind = "pie" , y = "total_victims", autopct='%1.0f%%', explode=explode )
# Out:
# <AxesSubplot:ylabel='total_victims'>

# %%
plt.figure(figsize = (30 ,8))

plo = sns.barplot(x = "year", y= "total_victims" , data = df, palette="deep")

# %%
sns.pairplot(df, hue = 'gender', palette = 'Blues')

# %%
tot = df['total_victims'].sum()
print (f"the total number of victims is {tot} victims")

tot2 = df['fatalities'].sum()
print (f"the total number of fatalities is {tot2} fatalities")

tot3 = df['injured'].sum()
print (f"the total number of injured is {tot3} injured")
# Out:
# the total number of victims is 2686 victims
# the total number of fatalities is 1101 fatalities
# the total number of injured is 1586 injured
